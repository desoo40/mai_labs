# %% [markdown]
# # Homework Lesson 2
#
# ## Задание
#
# * Создайте список из 1000 случайных строк, состоящих из латинских букв.
# * Каждая строка - случайной длиной от 3 до 8 символов.
# * Реализуйте бинарное дерево для строк
# * Реализуйте поиск ближайшего слова для заданного.

# %%
import random
import string

# %% [markdown]
# ## Генератор строк

# %%
def gen_strings(qty):
    l = []

    for i in range(qty):
        x = random.randint(3,8)
        l.append(''.join(random.choices(string.ascii_lowercase, k=x)))

    return l

# %% [markdown]
# ## Добавление элемента в дерево

# %%
def add_to_tree(s, node):
    if (s == node):
        print(f"'{s}' is already in tree")
        return

    if (s > node):
        if (bin_tree[node][1] == None):
            bin_tree[node][1] = s
            bin_tree[s] = [None, None]
        else:
            add_to_tree(s, bin_tree[node][1])
    
    else:
        if (bin_tree[node][0] == None):
            bin_tree[node][0] = s
            bin_tree[s] = [None, None]
        else:
            add_to_tree(s, bin_tree[node][0])

# %% [markdown]
# ## Поиск ближайшей строки

# %%
def find_nearest(f_str, node):
    if (f_str == node):
        print(f"Find same word! '{f_str}' == '{node}'")
        return

    if (f_str > node):
        if (bin_tree[node][1] == None):
            print(f"Nearest for '{f_str}' is '{node}'")
            return
        else:
            find_nearest(f_str, bin_tree[node][1])
    
    else:
        if (bin_tree[node][0] == None):
            print(f"Nearest for {f_str} is {node}")
            return
        else:
            find_nearest(f_str, bin_tree[node][0])

# %% [markdown]
# ## Печать дерева

# %%
def print_tree(node, n):
    if (node == None):
        return

    print('\t' * n, node)

    print_tree(bin_tree[node][1], n + 1)
    print_tree(bin_tree[node][0], n + 1)

# %%
list_str = gen_strings(1000)
list_str
# Out:
# ['fkqxg',
#  'dvxhar',
#  'seyjj',
#  'raf',
#  'lpdr',
#  'akutxvl',
#  'fwitdxp',
#  'bft',
#  'jiqje',
#  'ezmskoex',
#  'zrole',
#  'nrxz',
#  'jyyxiqjs',
#  'qdhe',
#  'zea',
#  'byzngg',
#  'gcvcivbx',
#  'yzfedalx',
#  'brdxd',
#  'fghlmtj',
#  'fcojs',
#  'omh',
#  'hifva',
#  'umnb',
#  'wxzvplsy',
#  'lgifimh',
#  'kueyu',
#  'fpfec',
#  'sukmtlu',
#  'hscxxrhn',
#  'ixxwpc',
#  'saqjok',
#  'uxpzfu',
#  'djuhjr',
#  'dnlx',
#  'fycdeoes',
#  'kpajvcvz',
#  'gepzhxv',
#  'cuvyefhh',
#  'ciuuqtd',
#  'qsgrtx',
#  'bmulwr',
#  'hjmexwsp',
#  'teprqq',
#  'uedwkn',
#  'zsfwbld',
#  'dinv',
#  'hkknkwzu',
#  'ktkxvmmo',
#  'wwq',
#  'gmcibtux',
#  'ahrrhq',
#  'wszgzoz',
#  'zvhl',
#  'ohkvn',
#  'bwhpvvbn',
#  'oqcpge',
#  'dommxck',
#  'kafvnln',
#  'pnlwex',
#  'xvvu',
#  'lekb',
#  'jgbto',
#  'rihyht',
#  'jat',
#  'ozqphpdz',
#  'kora',
#  'ogfzuzd',
#  'mrk',
#  'bukghb',
#  'fnsncmjm',
#  'ari',
#  'jry',
#  'vnlk',
#  'qtv',
#  'qaev',
#  'hjwv',
#  'epqicgkf',
#  'ueyxhqnv',
#  'znolfxoe',
#  'ukiflpmu',
#  'baqhxk',
#  'leioj',
#  'qoualvdi',
#  'xybe',
#  'tjciy',
#  'guas',
#  'wgn',
#  'uipwax',
#  'sarwwxoh',
#  'whnpugfp',
#  'hhs',
#  'oidk',
#  'ifi',
#  'oytuim',
#  'nvzps',
#  'rtdehhwe',
#  'ytsoc',
#  'lcmiwf',
#  'cixbymfl',
#  'oymightm',
#  'vihp',
#  'cptrbr',
#  'myzzoq',
#  'vdnhzmj',
#  'xaagvrx',
#  'fxt',
#  'ybel',
#  'pesorvt',
#  'ursh',
#  'bexsrz',
#  'zssyghes',
#  'dzpbykj',
#  'nlxxyd',
#  'mhc',
#  'awkbi',
#  'uvndox',
#  'mwktwrpo',
#  'qaaxdjb',
#  'wld',
#  'mbgf',
#  'balftz',
#  'fydl',
#  'gwpjtd',
#  'qyl',
#  'gno',
#  'btsi',
#  'fhijlude',
#  'rjzcoo',
#  'ayd',
#  'pbu',
#  'djdxgb',
#  'fcsk',
#  'hjxwgrfe',
#  'srgra',
#  'ibwmmlhu',
#  'dgeg',
#  'nvt',
#  'upo',
#  'caah',
#  'xlduv',
#  'qwxyuv',
#  'gkakovlk',
#  'cmbd',
#  'yvws',
#  'xcbmmoci',
#  'coetabu',
#  'wiuwgd',
#  'yoaagcdg',
#  'dvq',
#  'izhy',
#  'oza',
#  'nkpzyu',
#  'wwajuzjb',
#  'xhqlon',
#  'aaflbg',
#  'fmfkixcx',
#  'chrsza',
#  'ecafet',
#  'wkafspcw',
#  'wnrdnk',
#  'eghmfyeb',
#  'jerm',
#  'qsr',
#  'waqy',
#  'hvnxjmz',
#  'cekemgd',
#  'dzbyerxo',
#  'eancu',
#  'vwurkv',
#  'deslzrtv',
#  'qcqn',
#  'sokjh',
#  'nszqtnz',
#  'ltpqsifl',
#  'wqqsohy',
#  'wwjh',
#  'mwpcdb',
#  'ohyprdj',
#  'cem',
#  'hjbupzf',
#  'ozcmsl',
#  'ybaz',
#  'suuff',
#  'pqghv',
#  'mzrsbbz',
#  'fxeiltpm',
#  'axr',
#  'uytblthr',
#  'vntkpq',
#  'cbeif',
#  'hrv',
#  'hdubwy',
#  'umwyz',
#  'wfacbfpl',
#  'ues',
#  'qbrtu',
#  'urvbb',
#  'jlul',
#  'umbaxt',
#  'awytg',
#  'ufm',
#  'xcaj',
#  'nnco',
#  'wvmm',
#  'zqravml',
#  'tsm',
#  'yzr',
#  'rylh',
#  'vuweyarf',
#  'iom',
#  'amttzr',
#  'jas',
#  'luaqvsrq',
#  'psrgbs',
#  'auhrphi',
#  'dkgtdbzu',
#  'lbxzxju',
#  'dnhopf',
#  'kgtnixy',
#  'yfdgnqmb',
#  'rgnysdxf',
#  'oyzi',
#  'yuyfo',
#  'ykpgjpqj',
#  'wpa',
#  'bln',
#  'asthbfpv',
#  'lujnf',
#  'ucepbh',
#  'ifzfic',
#  'zxjwonsg',
#  'oxechy',
#  'voubm',
#  'obwuwkdf',
#  'fydzftd',
#  'prgbry',
#  'dvxfmgw',
#  'rium',
#  'eediy',
#  'dyqfwkv',
#  'gvvi',
#  'fnjyy',
#  'zlnke',
#  'nrunbr',
#  'dynhwkwa',
#  'lsmmrvha',
#  'vyxxtv',
#  'jatawp',
#  'ygguabgf',
#  'rtv',
#  'pduqqu',
#  'lslgn',
#  'vtgggke',
#  'emns',
#  'mkfprbvw',
#  'vnuww',
#  'sskyp',
#  'fouy',
#  'emhbajnk',
#  'zvpvbend',
#  'skrpzc',
#  'krvsni',
#  'kvtxtdx',
#  'suaxzxuh',
#  'usg',
#  'mewjlpk',
#  'flp',
#  'nmjm',
#  'scxy',
#  'wjraquq',
#  'kqwle',
#  'czaoxly',
#  'iahwqnw',
#  'qch',
#  'ajwlhmi',
#  'qys',
#  'lfqkzj',
#  'tcex',
#  'qads',
#  'rrfojd',
#  'pytcbg',
#  'ydpe',
#  'kmzazl',
#  'kvjaoxpm',
#  'zawqnn',
#  'virixjmc',
#  'mzv',
#  'yqzf',
#  'bwjgay',
#  'drsoeo',
#  'mwh',
#  'qwctawek',
#  'djdno',
#  'lbblfni',
#  'ijysrtv',
#  'soreqvp',
#  'fogb',
#  'eybi',
#  'ijxxf',
#  'nqyob',
#  'dzoyy',
#  'pyqyt',
#  'ctdabww',
#  'rar',
#  'vgvmf',
#  'mjvt',
#  'spfclbe',
#  'pzhcebi',
#  'ctbula',
#  'dsquq',
#  'judh',
#  'nzlyzq',
#  'mrzxt',
#  'gczl',
#  'crmb',
#  'jwrvrljy',
#  'jkqrhg',
#  'bmfduijd',
#  'sqyj',
#  'lxs',
#  'lpynoss',
#  'zbruu',
#  'xspqnzeh',
#  'qqytd',
#  'jcgape',
#  'bvw',
#  'mnkeffkl',
#  'pikiuw',
#  'yjaqljwn',
#  'gwxcgl',
#  'kljzyr',
#  'zyyl',
#  'gzbuvhj',
#  'dzbk',
#  'paajm',
#  'htskikdt',
#  'atmtl',
#  'fbbfex',
#  'iqyaykcx',
#  'pifuql',
#  'apqklwte',
#  'ezqvuo',
#  'zjqcrr',
#  'kxumy',
#  'mlou',
#  'plgeedw',
#  'etggj',
#  'wmn',
#  'rgsgw',
#  'hec',
#  'tvhzj',
#  'lnekwmpw',
#  'pjsdbvo',
#  'uzkbwvn',
#  'ecql',
#  'zkc',
#  'hkojur',
#  'ohhul',
#  'pxiqgn',
#  'ynaazel',
#  'flfxa',
#  'erx',
#  'dajrs',
#  'cawlt',
#  'xbpxjx',
#  'svxp',
#  'ykpu',
#  'tjvzawea',
#  'iqpgwa',
#  'owqhc',
#  'ndcot',
#  'lhvkm',
#  'vrz',
#  'znaqy',
#  'tkli',
#  'gmufvt',
#  'cphnp',
#  'lvrnvvau',
#  'ealmuwkr',
#  'bgopfgk',
#  'xayp',
#  'podxqn',
#  'rcqg',
#  'wtcucobq',
#  'ugli',
#  'tddqfivu',
#  'wii',
#  'mjndmp',
#  'puf',
#  'jjlz',
#  'kxyje',
#  'peqc',
#  'holurhk',
#  'qzzc',
#  'jmeuta',
#  'jjsfkt',
#  'amarf',
#  'phsqqikx',
#  'liytdmj',
#  'mipyn',
#  'lwllnf',
#  'hdnitcd',
#  'vwhml',
#  'fojonv',
#  'tmnvoym',
#  'sqou',
#  'kaj',
#  'vaf',
#  'wuhup',
#  'cfnkshuq',
#  'mtpv',
#  'uav',
#  'vasvww',
#  'ilopzr',
#  'eeq',
#  'edrvh',
#  'frvfuhg',
#  'leoqveye',
#  'ucco',
#  'pzjhlhse',
#  'rmjd',
#  'chhmnb',
#  'hkihapw',
#  'vtyf',
#  'ikrd',
#  'elgao',
#  'tgplrnw',
#  'nbrqabqe',
#  'xikj',
#  'jkqax',
#  'uzkiq',
#  'xcqk',
#  'uazyctxt',
#  'lcoal',
#  'jcho',
#  'itxt',
#  'fccwpc',
#  'frnmry',
#  'qfl',
#  'tpzloci',
#  'cygqocal',
#  'jxb',
#  'wrhyba',
#  'hexh',
#  'padifd',
#  'azowclo',
#  'txxmi',
#  'hul',
#  'yxv',
#  'tgty',
#  'snskqffn',
#  'cihzs',
#  'rugwxpqc',
#  'cwmpp',
#  'bqml',
#  'avs',
#  'jaaxolru',
#  'xbvrsgi',
#  'ciooxx',
#  'iolwq',
#  'ktyigy',
#  'aaxy',
#  'djeq',
#  'tzaywhni',
#  'pot',
#  'jwalnizj',
#  'jojecwuv',
#  'gvpqlru',
#  'pdyig',
#  'wompu',
#  'winkahw',
#  'yvqku',
#  'kao',
#  'fmisy',
#  'iackqpga',
#  'qyuv',
#  'lulzv',
#  'hhizyzip',
#  'rrzpr',
#  'mjxwxo',
#  'yzepvsjb',
#  'uchshuv',
#  'uyvaxms',
#  'xswxz',
#  'ygmtufh',
#  'hkwp',
#  'fidgiuyu',
#  'coqnaz',
#  'mnq',
#  'tofgvn',
#  'cgmuwce',
#  'xggcj',
#  'pjrn',
#  'lex',
#  'quf',
#  'qjcvms',
#  'dmuhl',
#  'fylg',
#  'xul',
#  'neooqyw',
#  'thwtg',
#  'iureqeuf',
#  'jgefwsa',
#  'dncf',
#  'qutce',
#  'lbxzxfe',
#  'oqajuy',
#  'vtnag',
#  'ivf',
#  'cleqdglc',
#  'yjgxqdou',
#  'jqbuw',
#  'crzbkpgm',
#  'ekbdcf',
#  'ypzz',
#  'tcoand',
#  'jxmslc',
#  'oyh',
#  'xsl',
#  'amamwegb',
#  'iqygiclo',
#  'dcjgjezv',
#  'nefuusc',
#  'bss',
#  'fnzzni',
#  'xev',
#  'gufaiw',
#  'hkd',
#  'rpc',
#  'brn',
#  'wchgvgf',
#  'ucifbh',
#  'xpqomw',
#  'zfwgv',
#  'cpgb',
#  'gsx',
#  'tnpxfi',
#  'hglnj',
#  'kvtjfyu',
#  'jfm',
#  'zdyuyqtq',
#  'gdd',
#  'lljms',
#  'puaps',
#  'hthfekk',
#  'vsxyez',
#  'fncbp',
#  'ybcjiopy',
#  'glpfcdz',
#  'siyctyyb',
#  'mbqwpczn',
#  'pmsqp',
#  'kqtkns',
#  'nzn',
#  'kynxd',
#  'edmbf',
#  'mkija',
#  'wavksol',
#  'wvnds',
#  'xuokuelb',
#  'poruyzv',
#  'tmmcwl',
#  'fxwjg',
#  'eqivlphb',
#  'uwghdgv',
#  'lmge',
#  'xpkgob',
#  'pinzuhj',
#  'zajxtr',
#  'ujtb',
#  'dximvc',
#  'izljmm',
#  'tgazqpe',
#  'rjvgt',
#  'cen',
#  'hbmmbptm',
#  'hclfvur',
#  'fuvsjald',
#  'mgqvf',
#  'laok',
#  'nidked',
#  'wzi',
#  'zfvln',
#  'xatr',
#  'fotrsec',
#  'ixcpz',
#  'ttbgbmyl',
#  'dong',
#  'uyrslq',
#  'mlfd',
#  'fhoa',
#  'gfqxcmub',
#  'gvvsmss',
#  'ohsbuoat',
#  'hzprqv',
#  'uhr',
#  'rjtumhgk',
#  'txv',
#  'trkhgmvv',
#  'pqyp',
#  'bvpiij',
#  'mmcrivd',
#  'cxwgv',
#  'xruhqgka',
#  'mrpap',
#  'pmztogy',
#  'wdnpqh',
#  'izdsxio',
#  'cyraesyq',
#  'kxhjhb',
#  'jijhv',
#  'pcl',
#  'nfbfcdip',
#  'ecou',
#  'eydci',
#  'kgkzds',
#  'zsczg',
#  'cjzkeso',
#  'ndotg',
#  'lsmijm',
#  'tranl',
#  'ppdfipzj',
#  'uyetsxl',
#  'lpfxtoai',
#  'amxg',
#  'hhqb',
#  'migvducp',
#  'xkod',
#  'non',
#  'ckfca',
#  'tcvrxjju',
#  'kqx',
#  'zgcwl',
#  'aaupgh',
#  'joqen',
#  'tpiic',
#  'vaabih',
#  'ylcvt',
#  'elq',
#  'asxmiv',
#  'uwyknq',
#  'bap',
#  'pbenlvya',
#  'jstlianl',
#  'yiw',
#  'bifh',
#  'imnokl',
#  'buppzqem',
#  'nibg',
#  'pysji',
#  'xkrjz',
#  'ekbrf',
#  'ftnzkdol',
#  'ligwe',
#  'jwho',
#  'aey',
#  'dasmwtc',
#  'zaf',
#  'rucqa',
#  'zgfhzutv',
#  'hdimqn',
#  'jhom',
#  'rsnzoykj',
#  'ggiv',
#  'naozy',
#  'zxmcrtgx',
#  'cbgkiifs',
#  'fau',
#  'xhzrjvr',
#  'entmkb',
#  'mmxmyk',
#  'pgfrf',
#  'zmmfztoy',
#  'iuhishd',
#  'apgdug',
#  'rlfjwm',
#  'ayabvcdf',
#  'ntwzvhm',
#  'txqkjn',
#  'ubk',
#  'any',
#  'ayk',
#  'rmvz',
#  'hhodi',
#  'ifjk',
#  'xyfjyehs',
#  'bxrkajjt',
#  'ypehs',
#  'iarpxf',
#  'yboajpw',
#  'eiumitu',
#  'rcfczxod',
#  'qexekllr',
#  'wes',
#  'vbtngvwj',
#  'cpicnb',
#  'abtrru',
#  'nuen',
#  'iqm',
#  'swsbjdb',
#  'koe',
#  'oxhmnj',
#  'gavljs',
#  'pdexq',
#  'kwrtrem',
#  'yfvm',
#  'lrjywegl',
#  'tpjfgopr',
#  'pjyb',
#  'ctje',
#  'wcpiyiv',
#  'lre',
#  'umbysrrx',
#  'xfyvv',
#  'qukiwyfm',
#  'myjfcxg',
#  'aligsp',
#  'nrxyuci',
#  'csvewfva',
#  'fqhcgs',
#  'wnphccin',
#  'lbu',
#  'iwbpqn',
#  'lraxj',
#  'zekjcrpb',
#  'zmd',
#  'mgdol',
#  'rnqyjhzj',
#  'xsevvts',
#  'ysvarn',
#  'djskobz',
#  'yordq',
#  'bzqrx',
#  'wypzqqja',
#  'ydyo',
#  'dwmpiucy',
#  'czdif',
#  'nth',
#  'qvpcdifo',
#  'qkuhal',
#  'uxq',
#  'shhdny',
#  'qzi',
#  'nmij',
#  'qfcrpw',
#  'wflhkzhw',
#  'bbkmlz',
#  'yuxqqp',
#  'tolrhjj',
#  'aaacpkp',
#  'nnf',
#  'ccesekvg',
#  'icbsd',
#  'mnlojn',
#  'uhv',
#  'xpg',
#  'damcqx',
#  'luan',
#  'vbarff',
#  'sovosuif',
#  'smfap',
#  'css',
#  'jxk',
#  'lnqae',
#  'nyxu',
#  'rlzqho',
#  'xgnuxzad',
#  'jbdp',
#  'kwscayew',
#  'dpdpjx',
#  'flqjgovc',
#  'bha',
#  'fsi',
#  'ybxakeh',
#  'qtayph',
#  'chdryj',
#  'uvkotzmm',
#  'aax',
#  'qpxtrobb',
#  'cxwcvqwl',
#  'aqpxsyo',
#  'prj',
#  'zqzioi',
#  'pkmekum',
#  'vwasyx',
#  'cbhowjt',
#  'axti',
#  'yupxxfzt',
#  'pnb',
#  'nri',
#  'zmlibe',
#  'cvyajz',
#  'zvtdlipz',
#  'ozsjrii',
#  'kbaceltn',
#  'vhqtlnm',
#  'vtzjwr',
#  'rzkcmqsa',
#  'yeg',
#  'qkxji',
#  'cwriolm',
#  'nlyda',
#  'acv',
#  'uwl',
#  'iqu',
#  'czabmafm',
#  'eaaa',
#  'zynt',
#  'pug',
#  'ocei',
#  'awmr',
#  'hss',
#  'fjqf',
#  'bkwaj',
#  'yfdqj',
#  'rctqeflz',
#  'lsfq',
#  'eyma',
#  'pybveeiu',
#  'xrbxzkwb',
#  'qpqo',
#  'jbyzqrug',
#  'sdvzfyd',
#  'bpck',
#  'qsuuk',
#  'kip',
#  'xnzmer',
#  'kkwv',
#  'rhnpwdt',
#  'tbc',
#  'meomn',
#  'qkgoqu',
#  'cnma',
#  'doq',
#  'atincre',
#  'xnzkqics',
#  'bwgwlafy',
#  'qhawvzv',
#  'xstjiskm',
#  'tkizd',
#  'yoa',
#  'yviaf',
#  'mflfh',
#  'wpkcxvns',
#  'rrsgp',
#  'jjuotinr',
#  'xkgxjjrv',
#  'lhi',
#  'bwyf',
#  'durq',
#  'sdoh',
#  'tcouwqf',
#  'vool',
#  'snp',
#  'ygqfynfd',
#  'oexmu',
#  'txoqlvqb',
#  'khcr',
#  'anavlvof',
#  'csu',
#  'utfveybp',
#  'lyei',
#  'luda',
#  'jruqnyo',
#  'ykardcbf',
#  'rffpy',
#  'qtjpabm',
#  'ppanv',
#  'yjeo',
#  'gecefdb',
#  'pbasgkyi',
#  'mkzptxbn',
#  'inlbvoc',
#  'prm',
#  'ksn',
#  'junhsu',
#  'xwpubrid',
#  'nqo',
#  'psekzdm',
#  'dfxzer',
#  'vnc',
#  'ivwm',
#  'vnwds',
#  'dzws',
#  'hhfgamf',
#  'uenyavam',
#  'qkta',
#  'juxtmj',
#  'kmzm',
#  'nqltghj',
#  'pppuywd',
#  'yoxjijdq',
#  'kkqy',
#  'vcfqp',
#  'oqdmt',
#  'ugipk',
#  'pmt',
#  'clkk',
#  'dwxwa',
#  'cvjplh',
#  'vnptyhco',
#  'gmw',
#  'gps',
#  'hklckr',
#  'guc',
#  'quwntxch',
#  'xvh',
#  'yvbgt',
#  'cbue',
#  'favzeg',
#  'tscn',
#  'eswx',
#  'lauadv',
#  'nbrzdlb',
#  'dpvesupx',
#  'knm',
#  'mzmj',
#  'owiozfn',
#  'homym',
#  'uizt',
#  'aotxshj',
#  'vabggpp',
#  'mnjort',
#  'xuodn',
#  'mfgn',
#  'hdeuvtz',
#  'sziptnl',
#  'iclhsd',
#  'rssmgmns',
#  'ydt',
#  'mume',
#  'bagpvsu',
#  'pdrcwkqg',
#  'dlfhmz',
#  'qnmvj',
#  'fayhi',
#  'jou',
#  'qvtuirhk',
#  'baj',
#  'ioj',
#  'qbbkwu',
#  'jhf',
#  'gup',
#  'vwza',
#  'cbnqci',
#  'ugq',
#  'elxjts',
#  'ssbmmgm',
#  'crd',
#  'bozxofpf',
#  'kjhr',
#  'cvlr',
#  'jlvhfm',
#  'jozfxfb',
#  'oxsu',
#  'favecjkk',
#  'xoz',
#  'ibcy',
#  'kxolqsa',
#  'slplrn',
#  'skryw',
#  'vyiqwyw',
#  'izukjcpu',
#  'gzqopr',
#  'jjo',
#  'tqgsqlvu',
#  'dglyr',
#  'sbpa',
#  'rinlr',
#  'auga',
#  'hzfapsni',
#  'ptszrpp',
#  'snfxn',
#  'zcva',
#  'yzmfia',
#  'hdkbkvl',
#  'qheeibij',
#  'vdwbvpi',
#  'aupx',
#  'hbnusfv',
#  'vkvq',
#  'xqxmet',
#  'xrte',
#  'njmm',
#  'khuqc',
#  'fdy',
#  'jmakyyyp',
#  'dggxy',
#  'fkpt',
#  'pghw',
#  'zgvgopjo',
#  'kzlf',
#  'hcuvjndy',
#  'rusqcv',
#  'ddrb',
#  'jja',
#  'ckv',
#  'ahkgyfqq',
#  'fyl']

# %%
root = list_str.pop(0) ## корень дерева - первый элемент списка

bin_tree = {} # дерево будет реализовано на словарях
bin_tree[root] = [None, None] # ключом является строка, дети - список из двух элементов - левый и правый соотвественно

for i in list_str:
    add_to_tree(i, root)

#print_tree(root, 0)

# %%
find_nearest('egkok', root)
# Out:
# Nearest for egkok is eiumitu

# %%
add_to_tree('zgvgopjo', root)
# Out:
# 'zgvgopjo' is already in tree
